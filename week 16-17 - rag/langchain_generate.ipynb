# %%
# Let's play around with generating text using LangChain with Ollama

# %%
# Generate text based on a prompt

from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama.llms import OllamaLLM

template = """
Question: {question}

Answer: Let's think step by step.
"""

prompt = ChatPromptTemplate.from_template(template)
model = OllamaLLM(model="llama3.2:1b")
chain = prompt | model

response = chain.invoke({"question": "How do you take a shower?"})
print(response)
# Out:
# Step one is to gather all the necessary items, which includes the water temperature setting, shampoo and conditioner, body wash or soap, towels, and any additional supplies such as a loofah or washcloth.
#
# Step two involves filling the bathtub or shower with warm or hot water. Some people prefer warm water for relaxation, while others like it hotter for a more invigorating experience.
#
# Step three is to apply the right amount of body wash or soap to your skin and work it into a lather. You may want to use a specific type of soap or body wash depending on your skin type and personal preferences.
#
# Step four involves applying shampoo and conditioner, working them into a rich lather, and massaging them into your hair for a thorough clean.
#
# Step five is rinsing the soap off your body thoroughly, paying special attention to areas like the armpits, feet, and groin. You may want to use warm or hot water to help loosen any remaining dirt or impurities.
#
# ...

# %%
# Generate text based on a prompt with an image

import base64
from io import BytesIO
from PIL import Image
import matplotlib.pyplot as plt

def convert_to_base64(pil_image):
    buffered = BytesIO()
    pil_image.save(buffered, format="PNG")
    img_str = base64.b64encode(buffered.getvalue()).decode("utf-8")
    return img_str

image_pil = Image.open("rsc/shower.png")
plt.imshow(image_pil)

image_b64 = convert_to_base64(image_pil)
llm = OllamaLLM(model="mistral-small3.2")

response = llm.invoke("What is in this picture?", images=[image_b64])
print(response)
# Out:
# The image depicts a modern shower setup with a person enjoying the shower. The shower system includes:
#
# 1. **Overhead Shower Head**: A large, circular shower head mounted on the ceiling, providing a cascading water flow.
# 2. **Handheld Showerhead**: A smaller, handheld showerhead attached to a flexible hose, allowing for directed water flow.
# 3. **Shower Arm and Holder**: The overhead shower head is connected via a shower arm, and the handheld showerhead is held in place by a bracket.
# 4. **Person**: A person is standing under the shower, with water flowing from both the overhead and handheld showerheads. The person appears to be washing their hair with shampoo.
#
# The overall design is sleek and modern, with a focus on functionality and comfort.
